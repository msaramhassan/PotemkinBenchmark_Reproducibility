# %%
import json

questions = json.load(open("definition_questions.json", "r"))

# %%
print("Definition Questions:")
for q in questions:
    print(q)
# Out:
# Definition Questions:
# {'Concept': 'Haiku', 'Domain': 'Literary Techniques', 'Articulate': 'What is a haiku?'}
# {'Concept': 'Shakespearean Sonnet', 'Domain': 'Literary Techniques', 'Articulate': 'What is a Shakespearean Sonnet?'}
# {'Concept': 'Analogy', 'Domain': 'Literary Techniques', 'Articulate': 'What is an analogy?'}
# {'Concept': 'Paradox', 'Domain': 'Literary Techniques', 'Articulate': 'What is a paradox?'}
# {'Concept': 'Anacoluthon', 'Domain': 'Literary Techniques', 'Articulate': 'What is an anacoluthon?'}
# {'Concept': 'Asyndeton', 'Domain': 'Literary Techniques', 'Articulate': 'What is an asyndeton?'}
# {'Concept': 'Hyperbaton', 'Domain': 'Literary Techniques', 'Articulate': 'What is a hyperbaton?'}
# {'Concept': 'Synesis', 'Domain': 'Literary Techniques', 'Articulate': 'What is a synesis?'}
# {'Concept': 'Accismus', 'Domain': 'Literary Techniques', 'Articulate': 'What is accismus?'}
# ...
